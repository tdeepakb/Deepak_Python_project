# %% [markdown]
# <a href="https://colab.research.google.com/github/tdeepakb/Deepak_Python_project/blob/master/Module7_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study- 1

# %% [markdown]
# 1. Using sklearn import the wine dataset
# 2. Split the data into train and test set
# 3. Train the model
# 4. Make Predictions
# 5. Check the performance of the model using r2_score.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/wine.csv')
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X = df.drop('Wine',axis=1)

# %%
y = df['Wine']

# %%
X
# Out:
#      Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0      14.23        1.71  2.43  15.6  127     2.80        3.06
# 1      13.20        1.78  2.14  11.2  100     2.65        2.76
# 2      13.16        2.36  2.67  18.6  101     2.80        3.24
# 3      14.37        1.95  2.50  16.8  113     3.85        3.49
# 4      13.24        2.59  2.87  21.0  118     2.80        2.69
# ..       ...         ...   ...   ...  ...      ...         ...
# 173    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1.1541804 , 1.2793251 , 2.51226242, 1.23069285, 1.91300059,
#        1.13035129, 1.94187532, 2.94819584, 1.49694681, 2.41201109,
#        1.16037956, 2.98753043, 1.38775636, 2.33885424, 1.12654184,
#        2.06364764, 2.22799032, 2.04483338, 1.1246299 , 1.94276148,
#        0.64134026, 1.55695857, 2.11968789, 3.06220511, 3.22947004,
#        3.05349207, 2.01947876, 1.7443841 , 2.08148491, 1.51558788,
#        1.17035709, 2.06708701, 2.61426528, 1.06014809, 1.01381639,
#        0.76877626, 3.25029252, 3.06234639, 1.51860049, 3.2418828 ,
#        1.21591904, 2.08686363, 1.74831061, 1.96392521, 2.57690389,
#        1.11412164, 1.75475891, 2.14980161, 2.99584692, 0.86327798,
#        2.04072383, 1.25515547, 0.93206549, 3.0741287 ])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9007762333580169
